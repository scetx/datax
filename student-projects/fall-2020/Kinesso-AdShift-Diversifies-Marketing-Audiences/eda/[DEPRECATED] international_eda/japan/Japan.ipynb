# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
file_path = 'impressions_one_hour.csv'
all_impressions_one_hour = pd.read_csv(file_path)
all_impressions_one_hour
# Out:
#         Unnamed: 0           log_entry_time  \
# 0                0  2020-09-09 04:29:56.000
# 1                1  2020-09-09 04:32:03.000
# 2                2  2020-09-09 04:33:43.000
# 3                3  2020-09-09 04:30:48.000
# 4                4  2020-09-09 04:31:46.000
# ...            ...                      ...
# 466478      466478  2020-09-09 04:16:11.000
# 466479      466479  2020-09-09 04:16:21.000
# 466480      466480  2020-09-09 04:16:33.000
# 466481      466481  2020-09-09 04:16:46.000
# 466482      466482  2020-09-09 04:16:57.000
#
#                                impression_id partner_id campaign_id  \
# 0       57f3aa7a-b276-47f7-a289-c78177691746    wsc5r0j     5txgufo
# 1       2ecfdbff-b25a-446f-af7c-ffd62baefb02    wsc5r0j     wwvbnz8
# 2       b6e82c65-2521-45fe-94d5-6c9d37060e84    wsc5r0j     vh2uh6e
# 3       9d26efa9-0cef-48d6-9619-4e73ce0a4829    wsc5r0j     vh2uh6e
# 4       364a7c77-96ef-473c-9675-5e8ad2a0dbc1    wsc5r0j     f6l0r6n
# ...                                      ...        ...         ...
# 466478  2fa02f7a-5496-4cdb-9d82-c182918c66f9    wsc5r0j     r4jrfrr
# 466479  c05dc607-2674-4c9a-a6d0-92e9c5a32f85    wsc5r0j     r4jrfrr
# 466480  f9aa68ac-64d9-4aac-9902-f888e3fe0839    wsc5r0j     r4jrfrr
# 466481  b9c75a4a-6f97-4c80-ad92-c727b379f2b2    wsc5r0j     r4jrfrr
# 466482  af595971-28ce-44ec-8b60-4bb879b805dd    wsc5r0j     r4jrfrr
#
#        ad_group_id private_contract_id audience_id creative_id ad_format  ...  \
# 0          nudgj9z                 NaN     8jx7gvs    4rpiqbve    320x50  ...
# 1          y7xgocb                 NaN     lzyn28h    mqxamjr3    320x50  ...
# 2          8z30tgg                 NaN     8w2jhha    dfmquuj0    300x50  ...
# 3          8z30tgg                 NaN     8w2jhha    x8c7u827    320x50  ...
# 4          3l27ron                 NaN     8jx7gvs    w4jiczfi    300x50  ...
# ...            ...                 ...         ...         ...       ...  ...
# 466478     je76ygx                 NaN     qiyblnv    kbh6oziz   300x250  ...
# 466479     je76ygx                 NaN     qiyblnv    u93fsb2z    320x50  ...
# 466480     je76ygx                 NaN     qiyblnv    u93fsb2z    320x50  ...
# 466481     je76ygx                 NaN     qiyblnv    kbh6oziz   300x250  ...
# 466482     je76ygx                 NaN     qiyblnv    u93fsb2z    320x50  ...
#
#         device_make device_model rendering_context carrier_id  \
# 0            Xiaomi     Redmi S2             InApp      577.0
# 1           Samsung     SM-J500M             InApp      503.0
# 2             Apple       iPhone             InApp      407.0
# 3             Apple       iPhone             InApp        NaN
# 4           Samsung     SM-G970F             InApp        NaN
# ...             ...          ...               ...        ...
# 466478        Apple       iPhone             InApp        NaN
# 466479        Apple       iPhone             InApp        NaN
# 466480        Apple         iPad             InApp        NaN
# 466481        Apple       iPhone             InApp        NaN
# 466482        Apple       iPhone             InApp        NaN
#
#        temperature_in_celsius_name temperature_bucket_start_in_celsius_name  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
# ...                            ...                                      ...
# 466478                         NaN                                      NaN
# 466479                         NaN                                      NaN
# 466480                       34.50                                     30.0
# 466481                       33.49                                     30.0
# 466482                         NaN                                      NaN
#
#         temperature_bucket_end_in_celsius_name  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 466478                                     NaN
# 466479                                     NaN
# 466480                                    38.0
# 466481                                    38.0
# 466482                                     NaN
#
#                  impression_placement_id   file_date advertiser_id
# 0       6a801e6f532e4aecb12316cbb04ebd30  2020-09-09       3ysyqec
# 1       6a801e6f532e4aecb12316cbb04ebd30  2020-09-09       3ysyqec
# 2       c1db878176df4e508d777a27c3412bb1  2020-09-09       3ysyqec
# 3                                    NaN  2020-09-09       3ysyqec
# 4                                    NaN  2020-09-09       3ysyqec
# ...                                  ...         ...           ...
# 466478                            106332  2020-09-09       3ysyqec
# 466479                             39467  2020-09-09       3ysyqec
# 466480                             78386  2020-09-09       3ysyqec
# 466481                            113796  2020-09-09       3ysyqec
# 466482                             45357  2020-09-09       3ysyqec
#
# [466483 rows x 52 columns]

# %%
## Data Cleaning
data_clean = all_impressions_one_hour.drop(columns=['Unnamed: 0', 'log_entry_time', 'partner_id', 
                                                             'private_contract_id', 'creative_id', 'ad_format',
                                                             'frequency', 'supply_vendor_publisher_id', 'deal_id',
                                                             'site', 'referrer_categories_list', 'fold_position',
                                                             'user_hour_of_week', 'ip_address', 'td_id', 'metro', 
                                                             'recency', 'language_code', 'media_cost', 
                                                             'fee_feature_cost', 'data_usage_total_cost', 
                                                             'ttd_cost_in_usd', 'partner_cost_in_usd', 
                                                             'advertiser_cost_in_usd', 'device_id', 
                                                             'processed_time', 'rendering_context', 
                                                             'temperature_in_celsius_name', 
                                                             'temperature_bucket_start_in_celsius_name', 
                                                             'temperature_bucket_end_in_celsius_name', 
                                                             'impression_placement_id', 'file_date', 
                                                             'advertiser_id', 'carrier_id', 'impression_id'])
data_clean = data_clean.dropna()
data_clean = data_clean.drop_duplicates()
data_clean.reset_index(drop=True, inplace=True)
data_clean.head()
# Out:
#   campaign_id ad_group_id audience_id supply_vendor  \
# 0     5txgufo     nudgj9z     8jx7gvs         mopub
# 1     wwvbnz8     y7xgocb     lzyn28h         mopub
# 2     vh2uh6e     8z30tgg     8w2jhha         mopub
# 3     vh2uh6e     8z30tgg     8w2jhha        google
# 4     f6l0r6n     3l27ron     8jx7gvs        google
#
#                                           user_agent  country          region  \
# 0  Mozilla/5.0 (Linux; Android 8.1.0; Redmi S2 Bu...    Spain        A Coruña
# 1  Mozilla/5.0 (Linux; Android 6.0.1; SM-J500M Bu...   Brazil  Santa Catarina
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 13_5_1 like...   France       Cote d'Or
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like...   France  Seine-Maritime
# 4  Mozilla/5.0 (Linux; Android 10; SM-G970F Build...  Germany         Bavaria
#
#                   city  device_type  os_family   os  browser  latitude  \
# 0                 Sada            4          6  154       15     43.35
# 1  São Miguel do Oeste            4          6  136       15    -26.71
# 2              Aiserey            4          5  168       15     47.17
# 3                Rouen            4          5  169       15     49.39
# 4          Seubersdorf            4          6  101       15     49.16
#
#    longitude zip_code device_make device_model
# 0      -8.25    15160      Xiaomi     Redmi S2
# 1     -53.51    89900     Samsung     SM-J500M
# 2       5.16    21110       Apple       iPhone
# 3       1.02    76000       Apple       iPhone
# 4      11.62    92358     Samsung     SM-G970F

# %%
# Select Japan's data
Japan_data = data_clean.copy()[data_clean['country'] == 'Japan']
Japan_data.reset_index(drop=True, inplace=True)
Japan_data.head()
# Out:
#   campaign_id ad_group_id audience_id    supply_vendor  \
# 0     r4jrfrr     40bujbh     qiyblnv  inMobi Exchange
# 1     r4jrfrr     je76ygx     qiyblnv            mopub
# 2     r4jrfrr     je76ygx     qiyblnv           smaato
# 3     r4jrfrr     je76ygx     qiyblnv           smaato
# 4     r4jrfrr     40bujbh     qiyblnv            mopub
#
#                                           user_agent country   region  \
# 0  Mozilla/5.0 (iPhone; CPU iPhone OS 13_7 like M...   Japan    Tokyo
# 1  Mozilla/5.0 (iPhone; CPU iPhone OS 13_5_1 like...   Japan  Saitama
# 2                             SmaatoBillNoticeSender   Japan    Tokyo
# 3                             SmaatoBillNoticeSender   Japan    Aichi
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like...   Japan    Hyōgo
#
#        city  device_type  os_family   os  browser  latitude  longitude  \
# 0     Tokyo            4          5  101       15     35.70     139.67
# 1    Konosu            4          5  168       15     36.06     139.53
# 2   Machida            4          5  157       15     35.73     139.48
# 3    Nagoya            4          5  169       15     35.05     136.96
# 4  Kakogawa            4          5  169       15     34.77     134.82
#
#    zip_code device_make device_model
# 0  102-0082       Apple       iPhone
# 1  365-0031       Apple       iPhone
# 2  194-0001       Apple       iPhone
# 3  460-0001       Apple       iPhone
# 4  675-0051       Apple       iPhone

# %%
Japan_data = Japan_data.drop(columns = ['country'])
Japan_data.head()
# Out:
#   campaign_id ad_group_id audience_id    supply_vendor  \
# 0     r4jrfrr     40bujbh     qiyblnv  inMobi Exchange
# 1     r4jrfrr     je76ygx     qiyblnv            mopub
# 2     r4jrfrr     je76ygx     qiyblnv           smaato
# 3     r4jrfrr     je76ygx     qiyblnv           smaato
# 4     r4jrfrr     40bujbh     qiyblnv            mopub
#
#                                           user_agent   region      city  \
# 0  Mozilla/5.0 (iPhone; CPU iPhone OS 13_7 like M...    Tokyo     Tokyo
# 1  Mozilla/5.0 (iPhone; CPU iPhone OS 13_5_1 like...  Saitama    Konosu
# 2                             SmaatoBillNoticeSender    Tokyo   Machida
# 3                             SmaatoBillNoticeSender    Aichi    Nagoya
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like...    Hyōgo  Kakogawa
#
#    device_type  os_family   os  browser  latitude  longitude  zip_code  \
# 0            4          5  101       15     35.70     139.67  102-0082
# 1            4          5  168       15     36.06     139.53  365-0031
# 2            4          5  157       15     35.73     139.48  194-0001
# 3            4          5  169       15     35.05     136.96  460-0001
# 4            4          5  169       15     34.77     134.82  675-0051
#
#   device_make device_model
# 0       Apple       iPhone
# 1       Apple       iPhone
# 2       Apple       iPhone
# 3       Apple       iPhone
# 4       Apple       iPhone

# %%
## Data Exploration

# %%
# Features/Variable names
Japan_data.columns
# Out:
# Index(['campaign_id', 'ad_group_id', 'audience_id', 'supply_vendor',
#        'user_agent', 'region', 'city', 'device_type', 'os_family', 'os',
#        'browser', 'latitude', 'longitude', 'zip_code', 'device_make',
#        'device_model'],
#       dtype='object')

# %%
# General data statistics
Japan_data.describe()
# Out:
#         device_type     os_family            os       browser      latitude  \
# count  26179.000000  26179.000000  26179.000000  26179.000000  26179.000000
# mean       3.938195      5.062722    158.011498     14.112266     35.379124
# std        0.240806      0.242467     22.101148      2.540219      2.939100
# min        3.000000      5.000000    101.000000      1.000000    -33.860000
# 25%        4.000000      5.000000    158.000000     15.000000     34.710000
# 50%        4.000000      5.000000    169.000000     15.000000     35.600000
# 75%        4.000000      5.000000    169.000000     15.000000     35.740000
# max        4.000000      6.000000    169.000000     15.000000     45.400000
#
#           longitude
# count  26179.000000
# mean     136.659276
# std       11.313557
# min      -97.820000
# 25%      135.520000
# 50%      139.450000
# 75%      139.710000
# max      151.190000

# %%
# Data Frame information (null, data type etc)
Japan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26179 entries, 0 to 26178
# Data columns (total 16 columns):
# campaign_id      26179 non-null object
# ad_group_id      26179 non-null object
# audience_id      26179 non-null object
# supply_vendor    26179 non-null object
# user_agent       26179 non-null object
# region           26179 non-null object
# city             26179 non-null object
# device_type      26179 non-null int64
# os_family        26179 non-null int64
# os               26179 non-null int64
# browser          26179 non-null int64
# latitude         26179 non-null float64
# longitude        26179 non-null float64
# zip_code         26179 non-null object
# device_make      26179 non-null object
# device_model     26179 non-null object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 3.2+ MB

# %%
# Histograms
Japan_data.hist(figsize=(13,10))
plt.show()

# %%
# campaign
print(Japan_data['campaign_id'].value_counts())
# ad group
print(Japan_data['ad_group_id'].value_counts())
# audience
print(Japan_data['audience_id'].value_counts())
# Out:
# r4jrfrr    26179
# Name: campaign_id, dtype: int64
# je76ygx    19395
# 40bujbh     5142
# yb20axt      883
# f6m9407      759
# Name: ad_group_id, dtype: int64
# qiyblnv    26179
# Name: audience_id, dtype: int64

# %%
# One campaign (from A Media Service Company); Four ad group assigned by TTD; One audience 
Japan_data['ad_group_id'].hist(figsize=(13,10))
plt.show()

# %%
# supply vendor (from which the impression was purchased)
print(Japan_data['supply_vendor'].value_counts())
Japan_data['supply_vendor'].hist(figsize=(13,10))
plt.show()
# Out:
# adgeneration                   12505
# mopub                           5208
# smaato                          4056
# inMobi Exchange                 1426
# fluct                           1115
# pubmatic                         831
# rubicon                          472
# ONE Mobile                       107
# Index Exchange                   100
# appnexus                          73
# aja                               70
# ironsource                        67
# kakao                             62
# AdColony                          51
# openx                             25
# yieldmo                            7
# Brightroll Exchange Display        3
# yieldone                           1
# Name: supply_vendor, dtype: int64

# %%
# user agent
print(Japan_data['user_agent'].value_counts())
# Out:
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148                                                          8145
# SmaatoBillNoticeSender                                                                                                                                                   4056
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_7 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148                                                            1352
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_5_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148                                                          1283
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148                                                             985
#                                                                                                                                                                          ...
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like Mac OS X) NicoManga-iOS/1.6.47 (SDK:13.6.1; DEVICE: iPhone X Global; UUID:b4f46d13ab254b8e0d1a4959b25e4569d6da6a55;)         1
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like Mac OS X) NicoManga-iOS/1.6.47 (SDK:13.6.1; DEVICE: iPhone 11 Pro Max; UUID:ad3b59834fca1a0b2137cec0623f4456409f5eed;)       1
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like Mac OS X) NicoManga-iOS/1.6.47 (SDK:13.6.1; DEVICE: iPhone XS; UUID:92ad1b55414e5f7f05e475e88b661822dc41776d;)               1
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like Mac OS X) NicoManga-iOS/1.6.47 (SDK:13.6.1; DEVICE: iPad Air 2 (WiFi); UUID:2ac5386ef1902c1169bddf6f325c2cb459be5147;)       1
# Mozilla/5.0 (iPhone; CPU iPhone OS 13_6_1 like Mac OS X) NicoManga-iOS/1.6.47 (SDK:13.6.1; DEVICE: iPhone 11; UUID:6a989641978e0bf72fdd1362e3b3643ec516bc26;)               1
# Name: user_agent, Length: 3426, dtype: int64

# %%
# region
Japan_data['region'].value_counts()
# Out:
# Tokyo            7642
# Ōsaka            2530
# Kanagawa         1436
# Aichi            1385
# Saitama          1180
# Hyōgo             925
# Fukuoka           916
# Chiba             885
# Hokkaido          872
# Shizuoka          554
# Kyoto             447
# Ibaraki           416
# Hiroshima         392
# Nara              323
# Okayama           314
# Gifu              313
# Niigata           295
# Miyagi            293
# Nagano            285
# Kumamoto          274
# Shiga             274
# Okinawa           272
# Fukushima-ken     270
# Mie               269
# Tochigi           264
# Gunma             241
# Ishikawa          201
# Kagoshima         197
# Ehime             186
# Yamaguchi         177
# Nagasaki          175
# Wakayama          174
# Yamanashi         153
# Toyama            150
# Oita              145
# Miyazaki          145
# Aomori            130
# Kagawa            126
# Tokushima         124
# Yamagata          121
# Akita             121
# Fukui             110
# Saga              109
# Kochi             109
# Shimane           104
# Iwate              95
# Tottori            60
# Name: region, dtype: int64

# %%
# city
Japan_data['city'].value_counts()
# bias between the city population with the people reached here
# Out:
# Osaka          1591
# Yokohama        789
# Suginami-ku     784
# Setagaya-ku     667
# Nagoya          650
#                ...
# Hirao             1
# Mizuko            1
# Miyawaka          1
# Hakuba            1
# Shirakuwa         1
# Name: city, Length: 1349, dtype: int64

# %%
# os family
print(Japan_data['os_family'].value_counts())
Japan_data['os_family'].hist(figsize=(13,10))
plt.show()
# 5: iOS, 6: Android
# huge bias， in Japan, Android about 53%, iOS about 45%, but it isn't reflected here!
# Out:
# 5    24537
# 6     1642
# Name: os_family, dtype: int64

# %%
# os
print(Japan_data['os'].value_counts())
Japan_data['os'].hist(figsize=(13,10))
plt.show()
# 101: other (exclude this data point, others are mainly iOS version)
# Out:
# 169    15676
# 101     3242
# 168     2002
# 157     1394
# 161      880
# 158      864
# 163      469
# 151      293
# 153      208
# 145      197
# 159      181
# 155      162
# 160      152
# 139      111
# 152       99
# 140       95
# 154       76
# 150       75
# 164        3
# Name: os, dtype: int64

# %%
# browser
print(Japan_data['browser'].value_counts())
Japan_data['browser'].hist(figsize=(13,10))
plt.show()
# 15: webview, 7: Safari, 6: Chrome, 1: Other
# Out:
# 15    23324
# 7      2460
# 6       394
# 1         1
# Name: browser, dtype: int64

# %%
#latitude
print(Japan_data['latitude'].value_counts())
#longitude
print(Japan_data['longitude'].value_counts())
# They are geographic coordination
# Out:
# 35.69    942
# 35.68    831
# 35.70    795
# 35.64    716
# 34.68    658
#         ...
# 37.07      1
# 37.19      1
# 33.04      1
# 42.84      1
# 42.52      1
# Name: latitude, Length: 947, dtype: int64
# 139.70    1030
# 139.64     834
# 139.71     634
# 139.65     566
# 139.67     554
#           ...
# 141.97       1
# 142.83       1
# 130.27       1
# 142.50       1
# 133.33       1
# Name: longitude, Length: 1240, dtype: int64

# %%
#zip code
Japan_data['zip_code'].value_counts()
# closely associated with city, region, longitude, latitude
# Out:
# 154-0017    435
# 160-0021    381
# 176-0001    315
# 102-0082    278
# 153-0061    252
#            ...
# 649-7111      1
# 010-0811      1
# 040-0001      1
# 981-4121      1
# 519-0121      1
# Name: zip_code, Length: 5739, dtype: int64

# %%
# device model
Japan_data['device_model'].value_counts()
# Out:
# iPhone        22688
# iPad           1533
# iPod Touch       98
# SH-01K           43
# iPhone 8         41
#               ...
# PRA-LX2           1
# A83               1
# C330              1
# SM-J600G          1
# HTV33             1
# Name: device_model, Length: 378, dtype: int64

# %%
# device type
print(Japan_data['device_type'].value_counts())
Japan_data['device_type'].hist(figsize=(13,10))
plt.show()
# 4: Mobile, 3: Tablet
# Out:
# 4    24561
# 3     1618
# Name: device_type, dtype: int64
