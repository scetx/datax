# %% [markdown]
# <a id='top'></a>
# # Homework
# ## Correlation
# > #### IEOR 135/290, Data-X: Applied Data Ventures
# > #### Author: Joshua Rafael Sanchez | UC Berkeley, B.S. IEOR, '20
# > In collaboration with Ikalaq Sidhu.
# > Email: joshuarafael@berkeley.edu
#
# > __About This Notebook:__ <br>
# > This notebook contains the homework associated from the Data-X lecture entitled "Correlation."  All questions under this homework are drawn from the concepts articulated on the slides aforementioned.
#
# > __Instructions:__ <br>
# > Feel free to add scratch cells above the answer cells to show your work towards the answer.
#
# > __Extra Resources Used:__ <br>
# > _Statistics Solutions: Advancement Through Clarity (statisticssolutions.com)_ [Link](https://www.statisticssolutions.com/wp-content/uploads/wp-post-to-pdf-enhanced-cache/1/correlation-pearson-kendall-spearman.pdf).
#
# > __Copyright:__ <br>
# > Feel free to use the code as you wish.

# %% [markdown]
# __________

# %% [markdown]
# <a id='table'></a>
# ## Table of Contents
# - ### Part 0: [Setup](#part_0)
# - ### Part 1: [The Basics](#part_1)
# - ### Part 2: [Theoretical Questions](#part_2)
# - ### Part 3: [Comparison of Correlation Type](#part_3)

# %% [markdown]
# ______

# %% [markdown]
# <a id='part_0'></a>
# ## Part 0: Setup
# Back to [Table of Contents](#table)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <a id='part_1'></a>
# ## Part 1: The Basics
# Back to [Table of Contents](#table)

# %% [markdown]
# Let's re-consider the table from the lecture:

# %% [markdown]
# ![title](q1_image.png)

# %% [markdown]
# If you wish to use code to create answers to the following questions, feel free to use the following variables:

# %%
col_ozone = np.array([4.59, 4.88, 4.71, 4.14, 2.01, 2.4, 4.08, 3.13, 2.05, 5.19, 3.59, 12.87])
col_temp = np.array([-0.2, 0.1, 0.9, 0.5, 4.3, 7.1, 5.2, 3.5, 3.2, 5.3, 3.0, 4.8])
col_humid = np.array([.757, .775, .813, .854, .935, .964, .935, .815, .883, .854, .926, .942])
col_death = np.array([199, 231, 210, 203, 224, 198, 180, 188, 168, 194, 223, 201])

# %% [markdown]
# ### Question 1a.
# As a refresher, what is $ E[X] $ and $ \sigma $ of each of the columns "Relative Humidity" and "# Deaths"? And, what is the covariance between the columns?  Put your answers in the cell below:

# %%
q1a_mean_relative_humidity = ...
q1a_mean_number_deaths = ...
q1a_std_relative_humidity = ...
q1a_std_number_deaths = ...
q1a_covariance = ...

q1a_mean_relative_humidity, q1a_mean_number_deaths, q1a_std_relative_humidity, q1a_std_number_deaths, q1a_covariance
# Out:
# (Ellipsis, Ellipsis, Ellipsis, Ellipsis, Ellipsis)

# %% [markdown]
# ### Question 1b.
# Calculate the  correlation coefficient between the same two columns.  __Show your work both with and without code__ (there's a Markdown cell included below), and then type in your final answer in the following cell.
#
# - Tip: You can use LaTeX to type the solution in Markdown.  If you are unfamilar with LaTeX and would like to learn more, check out [Question 3e](#3e).
# - Note: You don't have to manually do all the additions, just type in the appropriate formula and the main steps needed to get to the solution.
# - Hint: You've already calculated the main components needed for the solution. :)

# %% [markdown]
# __Work:__

# %%
q1b = ...
q1b
# Out:
# Ellipsis

# %% [markdown]
# ### Question 1c.
# In general, what does the correlation cofficient tell you about the relationship between the two columns? __Answer in the Markdown cell below.__

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### Question 1d.
# Which two columns seem to have the __strongest linear relationship__? __Answer the names of the columns__ as an array of strings.
# - Tip: If you want to use code, create and use a Pandas DataFrame.
# - Tip: What did you answer in Question 1c?

# %%
q1d = ...
q1d
# Out:
# Ellipsis

# %% [markdown]
# Now, consider the matrix of numbers generated below:

# %% [markdown]
# |   | A | B | C | D | E |
# |---|---|---|---|---|---|
# | row_1 | 0.1 | .32 | .2  | 0.4 | 0.8 |
# | row_2 | .23 | .18 | .56 | .61 | .12 |
# | row_3 | .9  | .3  | .6  | .5  | .3  |
# | row_4 | .34 | .75 | .91 | .19 | .21 |

# %% [markdown]
# If you wish to use code to create answers to the following questions, feel free to use this:

# %%
matrix = np.array([
    [0.1, .32, .2, 0.4, 0.8],
    [.23, .18, .56, .61, .12],
    [.9, .3, .6, .5, .3],
    [.34, .75, .91, .19, .21]])

# %% [markdown]
# ### Question 2a.
# What is the correlation matrix between the __rows__?  Create a matrix to represent this. <br>
# Hint: What does `np.corrcoef(x)` do?

# %%
q2a = ...
q2a
# Out:
# Ellipsis

# %% [markdown]
# ### Question 2b.
# What is the correlation matrix between the __columns__? Create a matrix to represent this. <br>
# Hint: The method `np.transpose(x)` may come in handy.

# %%
q2b = ...
q2b
# Out:
# Ellipsis

# %% [markdown]
# ### Question 2c.
# Which pairs of columns and pairs of rows appear to have a __very weak relationship__? Answer in the __Markdown cell__ below.  Just puts of names of rows/columns in their respective pairs.
# - Note: Clarify the parameters of your answer.
# - Hint: Reference the correlation matrices you have made above.
# - Tip: We found __6__ pairs that had a weak relationship.

# %% [markdown]
# __Answer:__

# %% [markdown]
# <a id='part_2'></a>
# ## Part 2: Theoretical Questions
# Back to [Table of Contents](#table)

# %% [markdown]
# For the following questions, answer with a boolean whether the preceding statement is `True` or `False`. <br>

# %% [markdown]
# ### Question 3a.
# The relationship between __correlation__ and __covariance__ can be represented in the following equation: <br> <br>
# $$ \rho_{X,Y} = corr(X,Y) = \frac{cov(X,Y)}{\sigma_{X}\sigma_{Y}} =  \frac{E[(X-\mu_{X})(Y-\mu_{Y})]}{\sigma_{X}\sigma_{Y}}$$

# %%
q3a = ...
q3a

# %% [markdown]
# ### Question 3b.
# Property: $ -1 \leq cor(X, Y) \leq 1 $,
# where $ X $ and $ Y $ are rows or columns of numbers.

# %%
q3b = ...
q3b

# %% [markdown]
# ### Question 3c.
# Property: $ cor(X, Y) = 1 \iff Y $ is any function of $ X $ with a positive slope.

# %%
q3c = ...
q3c
# Out:
# Ellipsis

# %% [markdown]
# ### Question 3d.
# Property: $ cor(X, Y) = -1 \iff Y $ is a linear function of $ X $ with a positive slope.

# %%
q3d = ...
q3d
# Out:
# Ellipsis

# %% [markdown]
# <a id='3e'></a>
# ### Question 3e.
# Show that <br> <br>
# $$ -1 \leq cor(X, Y) \leq 1 \Rightarrow - \sigma_{X}\sigma_{Y} \leq cov(X, Y) \leq \sigma_{X}\sigma_{Y} $$
# <br> <br> Use the LaTeX commands.  (This should only require a little bit of algebra.  __We used LaTeX here to express the answer.__)
# - Tip: Use LaTeX.  LaTeX is a document preparation system for high-quality typesetting.  Check out some cool LaTeX commands here: [LaTex Mathematics](<https://en.wikibooks.org/wiki/LaTeX/Mathematics>)
#     - Surround code dollar sign to start LaTeX documentation in Markdown, and use two dollar signs to create LaTeX in its own line.
# <br>
# - Tip: LaTeX commands that may be helpful, which I used to type my solution in LaTeX:
#     - `\leq`: creates a less than or equal to sign. ($ \leq $)
#     - `\sigma`: creates a lowercase sigma. ($ \sigma $)
#     - `\Rightarrow`: created an implies sign. ($ \Rightarrow $)
#     - `\frac`: creates a fraction. add brackets to add content. ($ \frac{1}{2} $)
#     - `<br>`: create a space between lines.

# %% [markdown]
# __Put answer here:__

# %% [markdown]
# ### Question 3f.
# For each of the descriptions, type in the name of the method associated with that description, as a __string__. Variables are provided in the cell below.
# - 1. Method that uses the standard correlation coefficient.
# - 2. Method that uses a coefficient that explicitly uses the numbers of concordant and discordant pairs.
# - 3. Method in which its coefficient uses the covariance of the rank variables (ordinal variables).

# %%
q3f_1 = ...
q3f_2 = ...
q3f_3 = ...

q3f_1, q3f_2, q3f_3
# Out:
# (Ellipsis, Ellipsis, Ellipsis)

# %% [markdown]
# ________

# %% [markdown]
# End of document. Back to [Top](#top).
