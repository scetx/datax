# %%
# Remove warnings
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
# %matplotlib inline 

import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

import re

from nltk.tokenize import sent_tokenize # tokenizes sentences
from nltk.stem import PorterStemmer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

eng_stopwords = stopwords.words('english')

import bs4 as bs

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

from google.colab import drive
drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Mounted at /content/drive

# %% [markdown]
# ## Import Data

# %%
train = pd.read_csv("./drive/My Drive/Data-X: GGWP Toxic Behavior Public Data/data/train[1].csv")
# test = pd.read_csv("./drive/My Drive/Data-X: GGWP Toxic Behavior Public Data/data/test[1].csv")
train.head()
# Out:
#                  id  ... identity_hate
# 0  0000997932d777bf  ...             0
# 1  000103f0d9cfb60f  ...             0
# 2  000113f07ec002fd  ...             0
# 3  0001b41b1c6bb37e  ...             0
# 4  0001d958c54c6e35  ...             0
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Data Processing

# %%
# Removes HTML tags (using beautifulsoup)
# Extract emoticons (aka smileys :D )
# Removes non-letters (using regular expression)
# Converts all words to lowercase letters and tokenizes them
# Removes all the English stopwords from the list of movie review words
# Join the words back into one string seperated by space, append the emoticons to the end
def review_cleaner(review):
    review = bs.BeautifulSoup(review).text
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', review)
    review = re.sub("[^a-zA-Z]", " ",review)
    review = review.lower().split()
    eng_stopwords = set(stopwords.words("english"))
    review = [w for w in review if not w in eng_stopwords]
    review = ' '.join(review+emoticons)
    return(review)

# get cleaned dataset

num_reviews = len(train['comment_text'])

review_clean_original = []

for i in range(0,num_reviews):
    if( (i+1)%500 == 0 ):
        # print progress
        print("Done with %d reviews" %(i+1)) 
    review_clean_original.append(review_cleaner(train['comment_text'][i]))
# Out:
# Done with 500 reviews
# Done with 1000 reviews
# Done with 1500 reviews
# Done with 2000 reviews
# Done with 2500 reviews
# Done with 3000 reviews
# Done with 3500 reviews
# Done with 4000 reviews
# Done with 4500 reviews
# Done with 5000 reviews
# Done with 5500 reviews
# Done with 6000 reviews
# Done with 6500 reviews
# Done with 7000 reviews
# Done with 7500 reviews
# Done with 8000 reviews
# Done with 8500 reviews
# Done with 9000 reviews
# Done with 9500 reviews
# Done with 10000 reviews
# Done with 10500 reviews
# Done with 11000 reviews
# Done with 11500 reviews
# Done with 12000 reviews
# Done with 12500 reviews
# Done with 13000 reviews
# Done with 13500 reviews
# Done with 14000 reviews
# Done with 14500 reviews
# Done with 15000 reviews
# Done with 15500 reviews
# Done with 16000 reviews
# Done with 16500 reviews
# Done with 17000 reviews
# Done with 17500 reviews
# Done with 18000 reviews
# Done with 18500 reviews
# Done with 19000 reviews
# Done with 19500 reviews
# Done with 20000 reviews
# Done with 20500 reviews
# Done with 21000 reviews
# Done with 21500 reviews
# Done with 22000 reviews
# Done with 22500 reviews
# Done with 23000 reviews
# Done with 23500 reviews
# Done with 24000 reviews
# Done with 24500 reviews
# Done with 25000 reviews
# Done with 25500 reviews
# Done with 26000 reviews
# Done with 26500 reviews
# Done with 27000 reviews
# Done with 27500 reviews
# Done with 28000 reviews
# Done with 28500 reviews
# Done with 29000 reviews
# Done with 29500 reviews
# Done with 30000 reviews
# Done with 30500 reviews
# Done with 31000 reviews
# Done with 31500 reviews
# Done with 32000 reviews
# Done with 32500 reviews
# Done with 33000 reviews
# Done with 33500 reviews
# Done with 34000 reviews
# Done with 34500 reviews
# Done with 35000 reviews
# Done with 35500 reviews
# Done with 36000 reviews
# Done with 36500 reviews
# Done with 37000 reviews
# Done with 37500 reviews
# Done with 38000 reviews
# Done with 38500 reviews
# Done with 39000 reviews
# Done with 39500 reviews
# Done with 40000 reviews
# Done with 40500 reviews
# Done with 41000 reviews
# Done with 41500 reviews
# Done with 42000 reviews
# Done with 42500 reviews
# Done with 43000 reviews
# Done with 43500 reviews
# Done with 44000 reviews
# Done with 44500 reviews
# Done with 45000 reviews
# Done with 45500 reviews
# Done with 46000 reviews
# Done with 46500 reviews
# Done with 47000 reviews
# Done with 47500 reviews
# Done with 48000 reviews
# Done with 48500 reviews
# Done with 49000 reviews
# Done with 49500 reviews
# Done with 50000 reviews
# Done with 50500 reviews
# Done with 51000 reviews
# Done with 51500 reviews
# Done with 52000 reviews
# Done with 52500 reviews
# Done with 53000 reviews
# Done with 53500 reviews
# Done with 54000 reviews
# Done with 54500 reviews
# Done with 55000 reviews
# Done with 55500 reviews
# Done with 56000 reviews
# Done with 56500 reviews
# Done with 57000 reviews
# Done with 57500 reviews
# Done with 58000 reviews
# Done with 58500 reviews
# Done with 59000 reviews
# Done with 59500 reviews
# Done with 60000 reviews
# Done with 60500 reviews
# Done with 61000 reviews
# Done with 61500 reviews
# Done with 62000 reviews
# Done with 62500 reviews
# Done with 63000 reviews
# Done with 63500 reviews
# Done with 64000 reviews
# Done with 64500 reviews
# Done with 65000 reviews
# Done with 65500 reviews
# Done with 66000 reviews
# Done with 66500 reviews
# Done with 67000 reviews
# Done with 67500 reviews
# Done with 68000 reviews
# Done with 68500 reviews
# Done with 69000 reviews
# Done with 69500 reviews
# Done with 70000 reviews
# Done with 70500 reviews
# Done with 71000 reviews
# Done with 71500 reviews
# Done with 72000 reviews
# Done with 72500 reviews
# Done with 73000 reviews
# Done with 73500 reviews
# Done with 74000 reviews
# Done with 74500 reviews
# Done with 75000 reviews
# Done with 75500 reviews
# Done with 76000 reviews
# Done with 76500 reviews
# Done with 77000 reviews
# Done with 77500 reviews
# Done with 78000 reviews
# Done with 78500 reviews
# Done with 79000 reviews
# Done with 79500 reviews
# Done with 80000 reviews
# Done with 80500 reviews
# Done with 81000 reviews
# Done with 81500 reviews
# Done with 82000 reviews
# Done with 82500 reviews
# Done with 83000 reviews
# Done with 83500 reviews
# Done with 84000 reviews
# Done with 84500 reviews
# Done with 85000 reviews
# Done with 85500 reviews
# Done with 86000 reviews
# Done with 86500 reviews
# Done with 87000 reviews
# Done with 87500 reviews
# Done with 88000 reviews
# Done with 88500 reviews
# Done with 89000 reviews
# Done with 89500 reviews
# Done with 90000 reviews
# Done with 90500 reviews
# Done with 91000 reviews
# Done with 91500 reviews
# Done with 92000 reviews
# Done with 92500 reviews
# Done with 93000 reviews
# Done with 93500 reviews
# Done with 94000 reviews
# Done with 94500 reviews
# Done with 95000 reviews
# Done with 95500 reviews
# Done with 96000 reviews
# Done with 96500 reviews
# Done with 97000 reviews
# Done with 97500 reviews
# Done with 98000 reviews
# Done with 98500 reviews
# Done with 99000 reviews
# Done with 99500 reviews
# Done with 100000 reviews
# Done with 100500 reviews
# Done with 101000 reviews
# Done with 101500 reviews
# Done with 102000 reviews
# Done with 102500 reviews
# Done with 103000 reviews
# Done with 103500 reviews
# Done with 104000 reviews
# Done with 104500 reviews
# Done with 105000 reviews
# Done with 105500 reviews
# Done with 106000 reviews
# Done with 106500 reviews
# Done with 107000 reviews
# Done with 107500 reviews
# Done with 108000 reviews
# Done with 108500 reviews
# Done with 109000 reviews
# Done with 109500 reviews
# Done with 110000 reviews
# Done with 110500 reviews
# Done with 111000 reviews
# Done with 111500 reviews
# Done with 112000 reviews
# Done with 112500 reviews
# Done with 113000 reviews
# Done with 113500 reviews
# Done with 114000 reviews
# Done with 114500 reviews
# Done with 115000 reviews
# Done with 115500 reviews
# Done with 116000 reviews
# Done with 116500 reviews
# Done with 117000 reviews
# Done with 117500 reviews
# Done with 118000 reviews
# Done with 118500 reviews
# Done with 119000 reviews
# Done with 119500 reviews
# Done with 120000 reviews
# Done with 120500 reviews
# Done with 121000 reviews
# Done with 121500 reviews
# Done with 122000 reviews
# Done with 122500 reviews
# Done with 123000 reviews
# Done with 123500 reviews
# Done with 124000 reviews
# Done with 124500 reviews
# Done with 125000 reviews
# Done with 125500 reviews
# Done with 126000 reviews
# Done with 126500 reviews
# Done with 127000 reviews
# Done with 127500 reviews
# Done with 128000 reviews
# Done with 128500 reviews
# Done with 129000 reviews
# Done with 129500 reviews
# Done with 130000 reviews
# Done with 130500 reviews
# Done with 131000 reviews
# Done with 131500 reviews
# Done with 132000 reviews
# Done with 132500 reviews
# Done with 133000 reviews
# Done with 133500 reviews
# Done with 134000 reviews
# Done with 134500 reviews
# Done with 135000 reviews
# Done with 135500 reviews
# Done with 136000 reviews
# Done with 136500 reviews
# Done with 137000 reviews
# Done with 137500 reviews
# Done with 138000 reviews
# Done with 138500 reviews
# Done with 139000 reviews
# Done with 139500 reviews
# Done with 140000 reviews
# Done with 140500 reviews
# Done with 141000 reviews
# Done with 141500 reviews
# Done with 142000 reviews
# Done with 142500 reviews
# Done with 143000 reviews
# Done with 143500 reviews
# Done with 144000 reviews
# Done with 144500 reviews
# Done with 145000 reviews
# Done with 145500 reviews
# Done with 146000 reviews
# Done with 146500 reviews
# Done with 147000 reviews
# Done with 147500 reviews
# Done with 148000 reviews
# Done with 148500 reviews
# Done with 149000 reviews
# Done with 149500 reviews
# Done with 150000 reviews
# Done with 150500 reviews
# Done with 151000 reviews
# Done with 151500 reviews
# Done with 152000 reviews
# Done with 152500 reviews
# Done with 153000 reviews
# Done with 153500 reviews
# Done with 154000 reviews
# Done with 154500 reviews
# Done with 155000 reviews
# Done with 155500 reviews
# Done with 156000 reviews
# Done with 156500 reviews
# Done with 157000 reviews
# Done with 157500 reviews
# Done with 158000 reviews
# Done with 158500 reviews
# Done with 159000 reviews
# Done with 159500 reviews

# %%
def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return 'n'

# get Lemmatized data
  # Lemmatization (paraphrased from Wiki): 
  # Lemmatization is the process of grouping together the inflected forms of a word so they can be analysed as a single item, 
  # identified by the word's lemma, or dictionary form.

review_clean_wnl = []

wnl = WordNetLemmatizer()

for i in range(0,num_reviews):
    if( (i+1)%500 == 0 ):
        # print progress
        print("Done with %d reviews" %(i+1)) 
    
    wnl_stems = []
    token_tag = pos_tag(review_clean_original[i].split())
    for pair in token_tag:
        res = wnl.lemmatize(pair[0],pos=get_wordnet_pos(pair[1]))
        wnl_stems.append(res)

    review_clean_wnl.append(' '.join(wnl_stems))
# Out:
# Done with 500 reviews
# Done with 1000 reviews
# Done with 1500 reviews
# Done with 2000 reviews
# Done with 2500 reviews
# Done with 3000 reviews
# Done with 3500 reviews
# Done with 4000 reviews
# Done with 4500 reviews
# Done with 5000 reviews
# Done with 5500 reviews
# Done with 6000 reviews
# Done with 6500 reviews
# Done with 7000 reviews
# Done with 7500 reviews
# Done with 8000 reviews
# Done with 8500 reviews
# Done with 9000 reviews
# Done with 9500 reviews
# Done with 10000 reviews
# Done with 10500 reviews
# Done with 11000 reviews
# Done with 11500 reviews
# Done with 12000 reviews
# Done with 12500 reviews
# Done with 13000 reviews
# Done with 13500 reviews
# Done with 14000 reviews
# Done with 14500 reviews
# Done with 15000 reviews
# Done with 15500 reviews
# Done with 16000 reviews
# Done with 16500 reviews
# Done with 17000 reviews
# Done with 17500 reviews
# Done with 18000 reviews
# Done with 18500 reviews
# Done with 19000 reviews
# Done with 19500 reviews
# Done with 20000 reviews
# Done with 20500 reviews
# Done with 21000 reviews
# Done with 21500 reviews
# Done with 22000 reviews
# Done with 22500 reviews
# Done with 23000 reviews
# Done with 23500 reviews
# Done with 24000 reviews
# Done with 24500 reviews
# Done with 25000 reviews
# Done with 25500 reviews
# Done with 26000 reviews
# Done with 26500 reviews
# Done with 27000 reviews
# Done with 27500 reviews
# Done with 28000 reviews
# Done with 28500 reviews
# Done with 29000 reviews
# Done with 29500 reviews
# Done with 30000 reviews
# Done with 30500 reviews
# Done with 31000 reviews
# Done with 31500 reviews
# Done with 32000 reviews
# Done with 32500 reviews
# Done with 33000 reviews
# Done with 33500 reviews
# Done with 34000 reviews
# Done with 34500 reviews
# Done with 35000 reviews
# Done with 35500 reviews
# Done with 36000 reviews
# Done with 36500 reviews
# Done with 37000 reviews
# Done with 37500 reviews
# Done with 38000 reviews
# Done with 38500 reviews
# Done with 39000 reviews
# Done with 39500 reviews
# Done with 40000 reviews
# Done with 40500 reviews
# Done with 41000 reviews
# Done with 41500 reviews
# Done with 42000 reviews
# Done with 42500 reviews
# Done with 43000 reviews
# Done with 43500 reviews
# Done with 44000 reviews
# Done with 44500 reviews
# Done with 45000 reviews
# Done with 45500 reviews
# Done with 46000 reviews
# Done with 46500 reviews
# Done with 47000 reviews
# Done with 47500 reviews
# Done with 48000 reviews
# Done with 48500 reviews
# Done with 49000 reviews
# Done with 49500 reviews
# Done with 50000 reviews
# Done with 50500 reviews
# Done with 51000 reviews
# Done with 51500 reviews
# Done with 52000 reviews
# Done with 52500 reviews
# Done with 53000 reviews
# Done with 53500 reviews
# Done with 54000 reviews
# Done with 54500 reviews
# Done with 55000 reviews
# Done with 55500 reviews
# Done with 56000 reviews
# Done with 56500 reviews
# Done with 57000 reviews
# Done with 57500 reviews
# Done with 58000 reviews
# Done with 58500 reviews
# Done with 59000 reviews
# Done with 59500 reviews
# Done with 60000 reviews
# Done with 60500 reviews
# Done with 61000 reviews
# Done with 61500 reviews
# Done with 62000 reviews
# Done with 62500 reviews
# Done with 63000 reviews
# Done with 63500 reviews
# Done with 64000 reviews
# Done with 64500 reviews
# Done with 65000 reviews
# Done with 65500 reviews
# Done with 66000 reviews
# Done with 66500 reviews
# Done with 67000 reviews
# Done with 67500 reviews
# Done with 68000 reviews
# Done with 68500 reviews
# Done with 69000 reviews
# Done with 69500 reviews
# Done with 70000 reviews
# Done with 70500 reviews
# Done with 71000 reviews
# Done with 71500 reviews
# Done with 72000 reviews
# Done with 72500 reviews
# Done with 73000 reviews
# Done with 73500 reviews
# Done with 74000 reviews
# Done with 74500 reviews
# Done with 75000 reviews
# Done with 75500 reviews
# Done with 76000 reviews
# Done with 76500 reviews
# Done with 77000 reviews
# Done with 77500 reviews
# Done with 78000 reviews
# Done with 78500 reviews
# Done with 79000 reviews
# Done with 79500 reviews
# Done with 80000 reviews
# Done with 80500 reviews
# Done with 81000 reviews
# Done with 81500 reviews
# Done with 82000 reviews
# Done with 82500 reviews
# Done with 83000 reviews
# Done with 83500 reviews
# Done with 84000 reviews
# Done with 84500 reviews
# Done with 85000 reviews
# Done with 85500 reviews
# Done with 86000 reviews
# Done with 86500 reviews
# Done with 87000 reviews
# Done with 87500 reviews
# Done with 88000 reviews
# Done with 88500 reviews
# Done with 89000 reviews
# Done with 89500 reviews
# Done with 90000 reviews
# Done with 90500 reviews
# Done with 91000 reviews
# Done with 91500 reviews
# Done with 92000 reviews
# Done with 92500 reviews
# Done with 93000 reviews
# Done with 93500 reviews
# Done with 94000 reviews
# Done with 94500 reviews
# Done with 95000 reviews
# Done with 95500 reviews
# Done with 96000 reviews
# Done with 96500 reviews
# Done with 97000 reviews
# Done with 97500 reviews
# Done with 98000 reviews
# Done with 98500 reviews
# Done with 99000 reviews
# Done with 99500 reviews
# Done with 100000 reviews
# Done with 100500 reviews
# Done with 101000 reviews
# Done with 101500 reviews
# Done with 102000 reviews
# Done with 102500 reviews
# Done with 103000 reviews
# Done with 103500 reviews
# Done with 104000 reviews
# Done with 104500 reviews
# Done with 105000 reviews
# Done with 105500 reviews
# Done with 106000 reviews
# Done with 106500 reviews
# Done with 107000 reviews
# Done with 107500 reviews
# Done with 108000 reviews
# Done with 108500 reviews
# Done with 109000 reviews
# Done with 109500 reviews
# Done with 110000 reviews
# Done with 110500 reviews
# Done with 111000 reviews
# Done with 111500 reviews
# Done with 112000 reviews
# Done with 112500 reviews
# Done with 113000 reviews
# Done with 113500 reviews
# Done with 114000 reviews
# Done with 114500 reviews
# Done with 115000 reviews
# Done with 115500 reviews
# Done with 116000 reviews
# Done with 116500 reviews
# Done with 117000 reviews
# Done with 117500 reviews
# Done with 118000 reviews
# Done with 118500 reviews
# Done with 119000 reviews
# Done with 119500 reviews
# Done with 120000 reviews
# Done with 120500 reviews
# Done with 121000 reviews
# Done with 121500 reviews
# Done with 122000 reviews
# Done with 122500 reviews
# Done with 123000 reviews
# Done with 123500 reviews
# Done with 124000 reviews
# Done with 124500 reviews
# Done with 125000 reviews
# Done with 125500 reviews
# Done with 126000 reviews
# Done with 126500 reviews
# Done with 127000 reviews
# Done with 127500 reviews
# Done with 128000 reviews
# Done with 128500 reviews
# Done with 129000 reviews
# Done with 129500 reviews
# Done with 130000 reviews
# Done with 130500 reviews
# Done with 131000 reviews
# Done with 131500 reviews
# Done with 132000 reviews
# Done with 132500 reviews
# Done with 133000 reviews
# Done with 133500 reviews
# Done with 134000 reviews
# Done with 134500 reviews
# Done with 135000 reviews
# Done with 135500 reviews
# Done with 136000 reviews
# Done with 136500 reviews
# Done with 137000 reviews
# Done with 137500 reviews
# Done with 138000 reviews
# Done with 138500 reviews
# Done with 139000 reviews
# Done with 139500 reviews
# Done with 140000 reviews
# Done with 140500 reviews
# Done with 141000 reviews
# Done with 141500 reviews
# Done with 142000 reviews
# Done with 142500 reviews
# Done with 143000 reviews
# Done with 143500 reviews
# Done with 144000 reviews
# Done with 144500 reviews
# Done with 145000 reviews
# Done with 145500 reviews
# Done with 146000 reviews
# Done with 146500 reviews
# Done with 147000 reviews
# Done with 147500 reviews
# Done with 148000 reviews
# Done with 148500 reviews
# Done with 149000 reviews
# Done with 149500 reviews
# Done with 150000 reviews
# Done with 150500 reviews
# Done with 151000 reviews
# Done with 151500 reviews
# Done with 152000 reviews
# Done with 152500 reviews
# Done with 153000 reviews
# Done with 153500 reviews
# Done with 154000 reviews
# Done with 154500 reviews
# Done with 155000 reviews
# Done with 155500 reviews
# Done with 156000 reviews
# Done with 156500 reviews
# Done with 157000 reviews
# Done with 157500 reviews
# Done with 158000 reviews
# Done with 158500 reviews
# Done with 159000 reviews
# Done with 159500 reviews

# %% [markdown]
# # Train Model

# %%
def predict_sentiment(cleaned_reviews, y=train["toxic"]):

    print("Creating the bag of words model!\n")
    # words to vector
    vectorizer = CountVectorizer(analyzer = "word",
                                 tokenizer = None,
                                 preprocessor = None,
                                 stop_words = None,
                                 max_features = 2000) 
    
    # Cannot really understand our test dataset so I still split the test set from the train set
    X_train, X_test, y_train, y_test = train_test_split(cleaned_reviews, y, random_state=0, test_size=.2)
    
    train_bag = vectorizer.fit_transform(X_train).toarray()
    test_bag = vectorizer.transform(X_test).toarray()

    print("Training the random forest classifier!\n")
    # Initialize a Random Forest classifier with 75 trees
    forest = RandomForestClassifier(n_estimators = 50) 
    forest = forest.fit(train_bag, y_train)

    train_predictions = forest.predict_proba(train_bag)
    test_predictions = forest.predict_proba(test_bag)
    
    train_auc = metrics.roc_auc_score(y_train, train_predictions[:, 1])
    valid_auc = metrics.roc_auc_score(y_test, test_predictions[:, 1])
    print("The training auc is: ", train_auc, "\n", "The validation auc is: ", valid_auc)
    
    return(forest,vectorizer)

# %% [markdown]
# # Output

# %%
print('Original Reviews')
forest1,vec1 = predict_sentiment(review_clean_original)
# Out:
# Original Reviews
# Creating the bag of words model!
#
# Training the random forest classifier!
#
# The training accuracy is:  0.9989319545427238
#  The validation accuracy is:  0.9200282155291643

# %%
print('Lemmatizing')
forest3,vec3 = predict_sentiment(review_clean_wnl)
# Out:
# Lemmatizing
# Creating the bag of words model!
#
# Training the random forest classifier!
#
# The training accuracy is:  0.9993001152483654
#  The validation accuracy is:  0.9341516540373583

# %% [markdown]
# # Get Validation Score

# %% [markdown]
# ## Preprocess Validation Data

# %%
val_data = pd.read_csv('./drive/My Drive/Data-X: GGWP Toxic Behavior Public Data/data/combined.csv')

# %%
val_clean = []

num_reviews = len(val_data)

for i in range(0,num_reviews):
    if( (i+1)%500 == 0 ):
        # print progress
        print("Done with %d reviews" %(i+1)) 
    val_clean.append(review_cleaner(val_data['text'][i]))

val_clean_wnl = []

wnl = WordNetLemmatizer()

for i in range(0,num_reviews):
    if( (i+1)%500 == 0 ):
        # print progress
        print("Done with %d reviews" %(i+1)) 
    
    wnl_stems = []
    token_tag = pos_tag(val_clean[i].split())
    for pair in token_tag:
        res = wnl.lemmatize(pair[0],pos=get_wordnet_pos(pair[1]))
        wnl_stems.append(res)

    val_clean_wnl.append(' '.join(wnl_stems))
# Out:
# Done with 500 reviews
# Done with 1000 reviews
# Done with 1500 reviews
# Done with 2000 reviews
# Done with 2500 reviews
# Done with 500 reviews
# Done with 1000 reviews
# Done with 1500 reviews
# Done with 2000 reviews
# Done with 2500 reviews

# %%
val_bag = vec3.transform(val_clean_wnl).toarray()

# %% [markdown]
# ## Get Validation Score

# %%
classes = ['toxic', 'severe_toxic', 'obscene', 'threat',
       'insult', 'identity_hate']

# %%
def train_validate(train_bag, val_bag, y_train, y_val, class_name):
    """
    Trains a random forest on the class and returns the auc score of the validation data

    """
    print("Training the random forest classifier for", class_name, "!\n")
    # Initialize a Random Forest classifier with 50 trees
    forest = RandomForestClassifier(n_estimators = 50) 
    forest = forest.fit(train_bag, y_train)

    val_predictions = forest.predict_proba(val_bag)
    
    val_auc = metrics.roc_auc_score(y_val, val_predictions[:, 1])
    print("The validation auc for", class_name, "is: ", val_auc, "\n")
    
    return val_auc

# %%
train_bag = vec3.transform(review_clean_wnl)
aucs = []
# Goes through each class
for class_name in classes:
    # Gets the validation score for each class
    val_auc = train_validate(train_bag, val_bag, train[class_name], val_data[class_name], class_name)
    aucs.append(val_auc)

# %% [markdown]
# ## Add Random Forest Average AUC to Model Results CSV

# %%
# model_results = pd.read_csv('./drive/My Drive/Data-X: GGWP Toxic Behavior Public Data/models/model_results.csv', index_col='Unnamed: 0')
# model_results = pd.concat([model_results, pd.DataFrame({'Model': ['Random Forest'], 'val_auc_score': [np.mean(aucs)]})])
# model_results.to_csv('./drive/My Drive/Data-X: GGWP Toxic Behavior Public Data/models/model_results.csv')
