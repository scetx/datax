# %%
# Initialize Otter Grader
import otter
grader = otter.Notebook()

# %% [markdown]
# # Homework 2

# %% [markdown]
# In this homework you will complete a couple of simple exercises in order to show your understanding with Python. If these exercises are challenging or new to you, you may want to reconsider taking the class and/or brush up on your Python skills. For the following exercises you are not allowed to use any Python packages (i.e. Numpy, Pandas, etc.).

# %% [markdown]
# ## Lists

# %% [markdown]
# 1.1 Create an empty Python list called 'a' in the cell below.
# <!--
# BEGIN QUESTION
# name: q1_1
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
a = [] 
# END SOLUTION

# %%
grader.check("q1_1")

# %% [markdown]
# 1.2 Store all values between 1-100 (inclusive) with increments of 3 (i.e. 1, 4, 7...) in 'a'.
# <!--
# BEGIN QUESTION
# name: q1_2
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
a = list(range(1, 103, 3))
# END SOLUTION
print(a)

# %%
grader.check("q1_2")

# %% [markdown]
# 1.3 Create another list called 'a2' with numbers from 2-46 (inclusive) with increments of 0.5 (i.e. 2, 2.5, 3...).
# <!--
# BEGIN QUESTION
# name: q1_3
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
a2 = list(range(20, 465, 5))
a2 = [n / 10.0 for n in a2]
# END SOLUTION
print(a2)

# %%
grader.check("q1_3")

# %% [markdown]
# 1.4 Double every even integer element from list 'a'. Store the results back in 'a'.
# <!--
# BEGIN QUESTION
# name: q1_4
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
new_list = [x*2 if idx%2 == 1 else x for idx, x in enumerate(a)]
a = new_list
# END SOLUTION
print(a)

# %%
grader.check("q1_4")

# %% [markdown]
# 1.5 Add all numbers in 'a' except for the 2nd and 21st elements (the 2nd element here means the element at list index 1).
# <!--
# BEGIN QUESTION
# name: q1_5
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
sum_a = 0
for i,val in enumerate(a):
    if i != 1 and i != 20:
        sum_a += val
# END SOLUTION
print(sum_a)

# %%
grader.check("q1_5")

# %% [markdown]
# 1.6 Calculate the mean of 'a'.
# <!--
# BEGIN QUESTION
# name: q1_6
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
mean_a = sum(a)/len(a)
# END SOLUTION
print(mean_a)

# %%
grader.check("q1_6")

# %% [markdown]
# 1.7 Delete all elements greater than the mean value from list 'a'
# <!--
# BEGIN QUESTION
# name: q1_7
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
a = [i for i in a if i < mean_a]
# END SOLUTION
print(a)

# %%
grader.check("q1_7")

# %% [markdown]
# ## Strings

# %% [markdown]
# 2.1 Create an empty list called 'b'.
# <!--
# BEGIN QUESTION
# name: q2_1
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
b = []
# END SOLUTION

# %%
grader.check("q2_1")

# %% [markdown]
# 2.2 Store the words in the sentence below as elements into the list 'b'.
#
# 'I am so excited about Data-X. It is important to be able to work with data.'
# <!--
# BEGIN QUESTION
# name: q2_2
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
sentence = 'I am so excited about Data-X. It is important to be able to work with data.'
b = sentence.split()
# END SOLUTION
print(b)

# %%
grader.check("q2_2")

# %% [markdown]
# 2.3 Return the count of the occurences of the lower-case letter 'e' in the list 'b'.
# <!--
# BEGIN QUESTION
# name: q2_3
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
occurences = 0
for word in b:
    occurences += word.count('e')
# END SOLUTION
print(occurences)

# %%
grader.check("q2_3")

# %% [markdown]
# 2.4 Replace every lower- or upper-case letter 'i' in the list b with a '1'.
# <!--
# BEGIN QUESTION
# name: q2_4
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
for i,word in enumerate(b):
    word2 = word.replace('I','1')
    word3 = word2.replace('i','1')
    b[i] = word3
# END SOLUTION
print(b)

# %%
grader.check("q2_4")

# %% [markdown]
# 2.5 Append the string "This is the end of the first HW." to the list 'b'.
# <!--
# BEGIN QUESTION
# name: q2_5
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
sentence = 'This is the end of the first HW.'
b.extend(sentence.split())
# END SOLUTION
print(b)

# %%
grader.check("q2_5")

# %% [markdown]
# 2.6 Print 'b' as ONE string backwards (starting with "WH tsrif...").
# <!--
# BEGIN QUESTION
# name: q2_6
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
print(" ".join(b)[::-1])
# END SOLUTION

# %%
grader.check("q2_6")

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# 3.1 Put the following in a dictionary called 'codes':
#
# Keys: 1001, 1002, 1003, 1004, 1005
# Values: 'Alpha', Beta, 'Gamma, 'Delta', 'Tau'
#
# then traverse the dictionary by its keys and change every value to be all lower case.
# <!--
# BEGIN QUESTION
# name: q3_1
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
keys = [1001, 1002, 1003, 1004, 1005]
values = ['Alpha', 'Beta', 'Gamma', 'Delta', 'Tau']
codes = dict.fromkeys(keys)
for i,key in enumerate(keys):
    codes[key] = values[i]

for key,value in codes.items():
    codes[key] = value.lower()
# END SOLUTION
print(codes)

# %%
grader.check("q3_1")

# %% [markdown]
# 3.2 Delete 'alpha' from the dictionary.
# <!--
# BEGIN QUESTION
# name: q3_2
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
codes = {k:v for k,v in codes.items() if v != 'alpha'}
# END SOLUTION
print(codes)

# %%
grader.check("q3_2")

# %% [markdown]
# ## Sets

# %% [markdown]
# 4.1 Create a set called 'c' with the all the odd numbers less than 10.
# <!--
# BEGIN QUESTION
# name: q4_1
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
c = set(range(1,10,2))
# END SOLUTION
print(c)

# %%
grader.check("q4_1")

# %% [markdown]
# 4.2 Create another set called 'd' with elements 2, 5, 10, 30.
# <!--
# BEGIN QUESTION
# name: q4_2
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
d = set([2,5,10,30])
# END SOLUTION
print(d)

# %%
grader.check("q4_2")

# %% [markdown]
# 4.3 Find the union between sets 'c' and 'd' and store this in a new set called 'e'.
# <!--
# BEGIN QUESTION
# name: q4_3
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
e = c.union(d)
# END SOLUTION
print(e)

# %%
grader.check("q4_3")

# %% [markdown]
# 4.4 Find the intersection between sets 'c' and 'd' and store this in a new set called 'f'.
# <!--
# BEGIN QUESTION
# name: q4_4
# manual: false
# points: 1
# -->

# %%
#your code here
# BEGIN SOLUTION
f = c.intersection(d)
# END SOLUTION
print (f)

# %%
grader.check("q4_4")

# %% [markdown]
# ## Function

# %% [markdown]
# 5.1 Create a function called 'f_med.' The input is an array, and the output is the medium number of that array. Note that, if total elements are even, the output should be the average of the two medium elements.
# <!--
# BEGIN QUESTION
# name: q5_1
# manual: false
# points: 2
# -->

# %%
#your code here

# BEGIN SOLUTION
import statistics
def f_med(arr):
    return statistics.median(arr)
# END SOLUTION

# %%
grader.check("q5_1")

# %% [markdown]
# 5.2 Create a function f_search which finds first and last position of element in decending sorted array. The inputs are an array of integers nums sorted in decending order and a target. The output is the starting and ending position of a given target value.
#
# If the target is not found in the array, return [-1, -1].
#
# Example 1:
#
# Input: nums = [9, 8, 8, 6, 4, 3, 1], target = 8
# Output: [1,2]
#
# Example 2:
#
# Input: nums = [9, 8, 8, 6, 4, 3, 1], target = 5
# Output: [-1,-1]
# <!--
# BEGIN QUESTION
# name: q5_2
# manual: false
# points: 2
# -->

# %%
#your code here
def f_search(arr, target):
# BEGIN SOLUTION
    idx_1=-1 #Starting index
    idx_2=-1 #Ending index
    for idx, value in enumerate(arr):

        if value == target:
            if idx_1 == -1:
                idx_1 = idx
                idx_2 = idx
            else:
                idx_2 = idx
        elif value < idx:
            break

# END SOLUTION
    return [idx_1, idx_2]

# %%
grader.check("q5_2")

# %% [markdown]
# # Submit
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output.
# **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to create a pdf for your reference.
import dsassign.to_pdf
dsassign.to_pdf.generate_pdf('pythonreview.ipynb', 'pythonreview.pdf')
